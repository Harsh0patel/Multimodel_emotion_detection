# %%
from sklearn.metrics import confusion_matrix, classification_report
import torch
from model import FusionClassifier

# %%
state_dict = torch.load("C:/Users/hp333/Desktop/Multimodel_emotion_detection/backend/models/fusion_model/Model_v2.pt", map_location="cpu")
Model = FusionClassifier()
Model.load_state_dict(state_dict['model_state_dict'])
Model.eval()
# Out:
# FusionClassifier(
#   (text_proj): Linear(in_features=768, out_features=512, bias=True)
#   (audio_proj): Linear(in_features=768, out_features=512, bias=True)
#   (video_proj): Linear(in_features=2048, out_features=512, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=1536, out_features=7, bias=True)
# )

# %%
audio_test = "C:/Users/hp333/Desktop/Multimodel_emotion_detection/data/fetures/test/audio"
video_test = "C:/Users/hp333/Desktop/Multimodel_emotion_detection/data/fetures/test/video"
text_test = "C:/Users/hp333/Desktop/Multimodel_emotion_detection/data/fetures/test/text"
with torch.no_grad():
    outputs = Model(text_test, audio_test, video_test)
    y_preds = torch.argmax(outputs, dim=1)
    y_pred_classes = y_preds.cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       3 text_test = "C:/Users/hp333/Desktop/Multimodel_emotion_detection/data/fetures/test/text"
#       4 with torch.no_grad():
# ----> 5     outputs = Model(text_test, audio_test, video_test)
#       6     y_preds = torch.argmax(outputs, dim=1)
#       7     y_pred_classes = y_preds.cpu().numpy()
#
# File c:\Users\hp333\Desktop\Multimodel_emotion_detection\myenv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\hp333\Desktop\Multimodel_emotion_detection\myenv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
# ...
