# %%
import kagglehub
import os

# Download latest version
path = kagglehub.dataset_download("samarwarsi/cmu-mosei")

print("Path to dataset files:", path)
print("\nFiles in dataset:")
for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Path to dataset files: C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1
#
# Files in dataset:
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\acoustics\CMU_MOSEI_COVAREP.csd
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\labels\CMU_MOSEI_Labels.csd
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\languages\CMU_MOSEI_TimestampedPhones.csd
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\languages\CMU_MOSEI_TimestampedWords.csd
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\languages\CMU_MOSEI_TimestampedWordVectors.csd
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\visuals\CMU_MOSEI_VisualFacet42.csd
# C:\Users\hp333\.cache\kagglehub\datasets\samarwarsi\cmu-mosei\versions\1\CMU-MOSEI\visuals\CMU_MOSEI_VisualOpenFace2.csd
